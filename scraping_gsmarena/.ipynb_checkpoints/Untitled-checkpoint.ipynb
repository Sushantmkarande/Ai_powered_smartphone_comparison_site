# %%
import pandas as pd

# %%
train = pd.read_csv('gsmarena.csv')

# %%
train.head()
# Out:
#               Model                               title  rate  \
# 0          Redmi 6A  Xiaomi Redmi 6 and Redmi 6A review   NaN
# 1           Mate 20               Huawei Mate 20 review   4.4
# 2          RX17 Pro       Oppo RX17 Pro hands-on review   NaN
# 3         iPhone XR              Apple iPhone XR review   NaN
# 4  Galaxy A7 (2018)     Samsung Galaxy A7 (2018) review   3.7
#
#                        tags  company  \
# 0            Xiaomi,Android   Xiaomi
# 1            Huawei,Android   Huawei
# 2     Oppo,Android,Hands-on     Oppo
# 3                 Apple,iOS    Apple
# 4  Samsung,Android,Dual SIM  Samsung
#
#                                               Images
# 0  https://cdn.gsmarena.com/imgroot/reviews/18/xi...
# 1  https://cdn.gsmarena.com/imgroot/reviews/18/hu...
# 2  https://cdn.gsmarena.com/imgroot/reviews/18/op...
# 3  https://cdn.gsmarena.com/imgroot/reviews/18/ip...
# 4  https://cdn.gsmarena.com/imgroot/reviews/18/sa...

# %%
train.dropna(subset= ['Model'], inplace=True)

# %%
train.to_csv('final.csv')

# %%
train.loc[4][3]
# Out:
# 'Samsung,Android,Dual SIM'

# %%
android = train[train['tags'].str.contains("Android",na=False)]

# %%
android.head()
# Out:
#               Model                               title  rate  \
# 0          Redmi 6A  Xiaomi Redmi 6 and Redmi 6A review   NaN
# 1           Mate 20               Huawei Mate 20 review   4.4
# 2          RX17 Pro       Oppo RX17 Pro hands-on review   NaN
# 4  Galaxy A7 (2018)     Samsung Galaxy A7 (2018) review   3.7
# 5           Phone 2                Razer Phone 2 review   3.9
#
#                        tags  company  \
# 0            Xiaomi,Android   Xiaomi
# 1            Huawei,Android   Huawei
# 2     Oppo,Android,Hands-on     Oppo
# 4  Samsung,Android,Dual SIM  Samsung
# 5             Razer,Android    Razer
#
#                                               Images
# 0  https://cdn.gsmarena.com/imgroot/reviews/18/xi...
# 1  https://cdn.gsmarena.com/imgroot/reviews/18/hu...
# 2  https://cdn.gsmarena.com/imgroot/reviews/18/op...
# 4  https://cdn.gsmarena.com/imgroot/reviews/18/sa...
# 5  https://cdn.gsmarena.com/imgroot/reviews/18/ra...

# %%
android['Model'] = ' ' + android['Model'].astype(str)
android['Model'] = android['company'] + android['Model']
# Out:
# c:\users\sushant\scrapy\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# c:\users\sushant\scrapy\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
android.head()
# Out:
#                       Model                               title  rate  \
# 0           Xiaomi Redmi 6A  Xiaomi Redmi 6 and Redmi 6A review   NaN
# 1            Huawei Mate 20               Huawei Mate 20 review   4.4
# 2             Oppo RX17 Pro       Oppo RX17 Pro hands-on review   NaN
# 4  Samsung Galaxy A7 (2018)     Samsung Galaxy A7 (2018) review   3.7
# 5             Razer Phone 2                Razer Phone 2 review   3.9
#
#                        tags  company  \
# 0            Xiaomi,Android   Xiaomi
# 1            Huawei,Android   Huawei
# 2     Oppo,Android,Hands-on     Oppo
# 4  Samsung,Android,Dual SIM  Samsung
# 5             Razer,Android    Razer
#
#                                               Images
# 0  https://cdn.gsmarena.com/imgroot/reviews/18/xi...
# 1  https://cdn.gsmarena.com/imgroot/reviews/18/hu...
# 2  https://cdn.gsmarena.com/imgroot/reviews/18/op...
# 4  https://cdn.gsmarena.com/imgroot/reviews/18/sa...
# ...

# %%
android['company'] = 'android > ' + android['company'].astype(str)
# Out:
# c:\users\sushant\scrapy\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
android['ID'] = android.index + 1
# Out:
# c:\users\sushant\scrapy\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
android.rename(columns={'Model': 'Name', 'title':'Short description','rate': 'Description','company': 'Categories' }, inplace=True)

# %%
android.head()
# Out:
#                        Name                   Short description  Description  \
# 0           Xiaomi Redmi 6A  Xiaomi Redmi 6 and Redmi 6A review          NaN
# 1            Huawei Mate 20               Huawei Mate 20 review          4.4
# 2             Oppo RX17 Pro       Oppo RX17 Pro hands-on review          NaN
# 4  Samsung Galaxy A7 (2018)     Samsung Galaxy A7 (2018) review          3.7
# 5             Razer Phone 2                Razer Phone 2 review          3.9
#
#                        tags         Categories  \
# 0            Xiaomi,Android   android > Xiaomi
# 1            Huawei,Android   android > Huawei
# 2     Oppo,Android,Hands-on     android > Oppo
# 4  Samsung,Android,Dual SIM  android > Samsung
# 5             Razer,Android    android > Razer
#
#                                               Images  ID
# 0  https://cdn.gsmarena.com/imgroot/reviews/18/xi...   1
# 1  https://cdn.gsmarena.com/imgroot/reviews/18/hu...   2
# ...

# %%
android.to_csv('android.csv')

# %%
train
# Out:
#                              Model  \
# 0                         Redmi 6A
# 1                          Mate 20
# 2                         RX17 Pro
# 3                        iPhone XR
# 4                 Galaxy A7 (2018)
# 5                          Phone 2
# 6                          Pixel 3
# 7                    Mi A2 (Mi 6X)
# 8                   One (P30 Play)
# 9                       Pixel 3 XL
# 10                        Honor 8X
# 11                       V40 ThinQ
# 13                     Mate 20 Pro
# 14       ZenFone Lite (L1) ZA551KL
# 15                      OnePlus 5T
# 16                       Realme U1
# 17                       Mi 8 Lite
# 18            iPad Pro 12.9 (2018)
# 19                        RX17 Pro
# 20                      6T McLaren
# 21                      6T McLaren
# 22                NEX Dual Display
# 23                   Honor Magic 2
# 24                       ROG Phone
# 25                   Honor 10 Lite
# ...

# %%
ios = train[train['tags'].str.contains("iOS",na=False)]
